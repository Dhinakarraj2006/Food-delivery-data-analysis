# %% [markdown]
# SQL BUSINESS ANALYSIS
#
# Q1 — Overall Delivery Performance
#
# Business Question:
# How many total orders are there, and what is the average delivery time?
#
# Result:
# Total Orders = 45,584
# Average Delivery Time = 26.29 minutes
#
# Business Insight:
# The dataset contains 45,584 food delivery orders, with an average delivery time of 26.29 minutes.

# %% [markdown]
# Q2 — Traffic Impact on Delivery Performance
#
# Business Question: How does traffic density affect the average delivery time?
#
# Result:
# Jam = 14,139 orders | Average Delivery Time = 31.18 minutes
# High = 4,423 orders | Average Delivery Time = 27.24 minutes
# Medium = 10,945 orders | Average Delivery Time = 26.70 minutes
# Unknown = 601 orders | Average Delivery Time = 26.54 minutes
# Low = 15,476 orders | Average Delivery Time = 21.27 minutes
#
# Business Insight:
# Jam traffic has the highest average delivery time at 31.18 minutes,
# while Low traffic has the lowest at 21.27 minutes. This indicates
# that higher traffic congestion is associated with longer delivery times.

# %% [markdown]
# Q3 — Weather Impact on Delivery Performance
#
# Business Question: How do weather conditions affect the average delivery time?
#
# Result:
# Cloudy = 7,533 orders | Average Delivery Time = 28.92 minutes
# Fog = 7,653 orders | Average Delivery Time = 28.91 minutes
# Unknown = 616 orders | Average Delivery Time = 26.55 minutes
# Windy = 7,422 orders | Average Delivery Time = 26.12 minutes
# Sandstorms = 7,494 orders | Average Delivery Time = 25.88 minutes
# Stormy = 7,584 orders | Average Delivery Time = 25.87 minutes
# Sunny = 7,282 orders | Average Delivery Time = 21.86 minutes
#
# Business Insight:
# Cloudy and Fog conditions have the highest average delivery times,
# at 28.92 and 28.91 minutes respectively. Sunny conditions have the
# lowest average delivery time at 21.86 minutes. This indicates that
# weather conditions can have a noticeable impact on delivery performance.

# %% [markdown]
# Q4 — Vehicle Impact on Delivery Performance
#
# Business Question: How does the type of vehicle affect the average delivery time?
#
# Result:
# Motorcycle = 26,429 orders | Average Delivery Time = 27.61 minutes
# Bicycle = 682 orders | Average Delivery Time = 26.43 minutes
# Scooter = 15,273 orders | Average Delivery Time = 24.48 minutes
# Electric Scooter = 3,814 orders | Average Delivery Time = 24.47 minutes
#
# Business Insight:
# Motorcycles have the highest average delivery time at 27.61 minutes,
# while Electric Scooters have the lowest at 24.47 minutes. This suggests
# that vehicle type may have an impact on delivery performance, with
# scooters and electric scooters showing faster average delivery times.

# %% [markdown]
# Q5 — Order Type Impact on Delivery Performance
#
# Business Question: How does the type of order affect the average delivery time?
#
# Result:
# Meal = 11,456 orders | Average Delivery Time = 26.42 minutes
# Snack = 11,530 orders | Average Delivery Time = 26.29 minutes
# Buffet = 11,277 orders | Average Delivery Time = 26.28 minutes
# Drinks = 11,321 orders | Average Delivery Time = 26.19 minutes
#
# Business Insight:
# The average delivery time is very similar across all order types,
# ranging from 26.19 to 26.42 minutes. Meal orders have the highest
# average delivery time at 26.42 minutes, while Drinks have the lowest
# at 26.19 minutes. This suggests that order type has very little impact
# on overall delivery time.

# %% [markdown]
# Q6 — City Impact on Delivery Performance
#
# Business Question: How does the city segment affect the average delivery time?
#
# Result:
# Semi-Urban = 164 orders | Average Delivery Time = 49.73 minutes
# Metropolitan = 34,087 orders | Average Delivery Time = 27.31 minutes
# Urban = 10,133 orders | Average Delivery Time = 22.98 minutes
# Unknown = 1,200 orders | Average Delivery Time = 22.06 minutes
#
# Business Insight:
# Semi-Urban has the highest average delivery time at 49.73 minutes.
# However, it contains only 164 orders, which is a very small portion
# of the dataset. Therefore, this result should be interpreted with
# caution and should not be generalized as an overall city-level trend.
#
# Among the larger and more representative segments, Metropolitan has
# the highest average delivery time at 27.31 minutes, while Urban has
# 22.98 minutes.

# %% [markdown]
# Q7 — Festival Impact on Delivery Performance
#
# Business Question: Does festival status affect the average delivery time?
#
# Result:
# Yes = 896 orders | Average Delivery Time = 45.52 minutes
# No = 44,460 orders | Average Delivery Time = 25.98 minutes
# Unknown = 228 orders | Average Delivery Time = 11.17 minutes
#
# Business Insight:
# Festival orders have a much higher average delivery time of 45.52
# minutes compared with non-festival orders at 25.98 minutes. This
# suggests that festival periods may be associated with longer delivery
# times. However, the Unknown category has only 228 orders and should
# not be used for a strong comparison.

# %% [markdown]
# Q8 — Multiple Deliveries Impact on Delivery Performance
#
# Business Question: How does the number of multiple deliveries affect the average delivery time?
#
# Result:
# 0 = 14,094 orders | Average Delivery Time = 22.88 minutes
# 1 = 29,144 orders | Average Delivery Time = 26.72 minutes
# 2 = 1,985 orders | Average Delivery Time = 40.45 minutes
# 3 = 361 orders | Average Delivery Time = 47.82 minutes
#
# Business Insight:
# Average delivery time increases as the number of multiple deliveries
# increases. Deliveries with 0 multiple deliveries have the lowest
# average time at 22.88 minutes, while deliveries with 3 multiple
# deliveries have the highest at 47.82 minutes. This indicates that
# handling multiple deliveries is strongly associated with longer
# delivery times in this dataset.

# %% [markdown]
#  Q9 — Delivery Person Ratings Impact on Delivery Performance
#
# Business Question:
# How does delivery-person rating relate to average delivery time?
#
# Result:
# Ratings 4.5 to 5.0 = 34,753 orders | Average Delivery Time = 23.64 to 24.64 minutes
# Ratings 4.0 to 4.4 = 6,694 orders | Average Delivery Time = 34.53 to 34.84 minutes
# Ratings below 4.0 = 2,229 orders | Average Delivery Time = 32.67 to 38.59 minutes
# Unknown = 1,908 orders | Average Delivery Time = 26.31 minutes
#
# Business Insight:
# Higher-rated delivery partners (ratings 4.5 to 5.0) achieve significantly faster delivery times averaging around 23 to 24 minutes. In contrast, delivery partners with ratings below 4.5 take substantially longer, averaging around 34 to 38 minutes. This indicates a strong positive correlation between delivery speed and higher customer ratings.

# %% [markdown]
# Q10 — Delivery Time Range Analysis (30 to 40 mins)
#
# Business Question:
# How many orders took between 30 and 40 minutes?
#
# Result:
# Orders between 30 and 40 minutes = 10,782 orders
#
# Business Insight:
# A total of 10,782 orders (approximately 23.65% of all deliveries) fall within the 30 to 40-minute window. This represents a substantial portion of moderately delayed orders that could benefit from route optimization and traffic-aware dispatching to reduce delivery times.

# %% [markdown]
# Q11 — Fast Deliveries Performance (Within 20 mins)
#
# Business Question:
# How many orders were delivered within 20 minutes?
#
# Result:
# Fast Deliveries (<= 20 mins) = 14,149 orders
#
# Business Insight:
# A total of 14,149 orders (approximately 31.04% of total deliveries) were successfully fulfilled within 20 minutes. This demonstrates that nearly one-third of the total order volume meets ultra-fast delivery standards, primarily driven by low traffic conditions and favorable weather.

# %% [markdown]
# Q12 — Delayed Deliveries Analysis (More than 40 mins)
#
# Business Question:
# How many orders took more than 40 minutes?
#
# Result:
# Delayed Orders (> 40 mins) = 4,037 orders
#
# Business Insight:
# A total of 4,037 orders (approximately 8.86% of total deliveries) experienced severe delays exceeding 40 minutes. These long delays are primarily linked to festive periods, severe traffic jams, adverse weather conditions, and multiple delivery assignments.

# %% [markdown]
# Q13 — Specific Categories using IN Operator
#
# Business Question:
# What is the average delivery time for Motorcycle and Scooter deliveries?
#
# Result:
# motorcycle = 26,429 orders | Average Delivery Time = 27.61 minutes
# scooter = 15,273 orders | Average Delivery Time = 24.48 minutes
#
# Business Insight:
# Between the two primary motorized two-wheeler categories, scooters are delivered faster on average by over 3.1 minutes compared to motorcycles. This comparison filtered specifically using the IN operator highlights the efficiency of lighter two-wheelers in navigating city traffic.

# %% [markdown]
# Q14 — Vehicle Categories Identification using DISTINCT
#
# Business Question:
# What are the different types of vehicles used for delivery?
#
# Result:
# Distinct Vehicle Types:
# 1. motorcycle
# 2. scooter
# 3. electric_scooter
# 4. bicycle
#
# Business Insight:
# The delivery fleet operates across 4 distinct vehicle categories: motorcycles, scooters, electric scooters, and bicycles. This validation confirms fleet categorization for logistics planning.

# %% [markdown]
# Q15 — Pattern Matching using LIKE Operator
#
# Business Question:
# How many delivery-person IDs start with a specific pattern (e.g., 'DE%')?
#
# Result:
# Matching Delivery Person IDs ('DE%') = 737 records
#
# Business Insight:
# Demonstrates pattern-matching functionality using the LIKE operator, successfully identifying 737 records associated with delivery person IDs starting with the 'DE' prefix for targeted data validation.

# %% [markdown]
# Q16 — Traffic Conditions with High Order Volumes (HAVING Clause)
#
# Business Question:
# Which traffic conditions have more than 5,000 orders?
#
# Result:
# Low = 15,476 orders | Average Delivery Time = 21.27 minutes
# Jam = 14,139 orders | Average Delivery Time = 31.18 minutes
# Medium = 10,945 orders | Average Delivery Time = 26.70 minutes
#
# Business Insight:
# Using the HAVING clause to filter aggregated traffic volumes above 5,000 orders isolates the top 3 dominant operating environments: Low, Jam, and Medium traffic. Together, these three categories account for over 89% of all delivery operations, with severe delays concentrated heavily during Jam conditions.

# %% [markdown]
# Q17 — Traffic Conditions Exceeding Overall Average Time (SUBQUERY)
#
# Business Question:
# Which traffic conditions have an average delivery time greater than the overall average delivery time?
#
# Result:
# Jam = Average Delivery Time = 31.18 minutes
# High = Average Delivery Time = 27.24 minutes
# Medium = Average Delivery Time = 26.70 minutes
# Unknown = Average Delivery Time = 26.54 minutes
#
# Business Insight:
# Using a subquery to compare against the overall operational baseline (26.29 minutes), Jam, High, Medium, and Unknown traffic categories all exceed the global average delivery duration. Specifically, Jam conditions perform worst, exceeding the dataset average by nearly 5 minutes per order.
