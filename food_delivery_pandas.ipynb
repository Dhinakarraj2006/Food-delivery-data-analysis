# %%
import pandas as pd

order= pd.read_csv(r"C:\Users\acer\Downloads\project1.zip",compression="zip")
order.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
order.shape
# Out:
# (45584, 20)

# %%
order.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
order.tail()
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 45579                      4.8            26.902328             75.794257
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 45579                   26.912328                    75.804257  24-03-2022
# ...

# %%
order.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
order.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries            float64
# Festival                        object
# City                            object
# Time_taken (min)                 int64
# dtype: object

# %%
order.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
order.duplicated().sum()
# Out:
# np.int64(0)

# %%
(order.isnull().sum() / len(order) * 100).sort_values(ascending=False)
# Out:
# Delivery_person_Ratings        4.185679
# Delivery_person_Age            4.067217
# Time_Orderd                    3.797385
# City                           2.632503
# multiple_deliveries            2.178396
# Weather_conditions             1.351351
# Road_traffic_density           1.318445
# Festival                       0.500176
# ID                             0.000000
# Delivery_person_ID             0.000000
# Restaurant_latitude            0.000000
# Restaurant_longitude           0.000000
# Time_Order_picked              0.000000
# Order_Date                     0.000000
# Delivery_location_latitude     0.000000
# Delivery_location_longitude    0.000000
# Type_of_vehicle                0.000000
# Type_of_order                  0.000000
# Vehicle_condition              0.000000
# Time_taken (min)               0.000000
# dtype: float64

# %%
order["Delivery_person_Age"] = order["Delivery_person_Age"].fillna(order["Delivery_person_Age"].median())
order["Delivery_person_Ratings"] = order["Delivery_person_Ratings"].fillna(order["Delivery_person_Ratings"].median())
order["multiple_deliveries"] = order["multiple_deliveries"].fillna(order["multiple_deliveries"].median())


order["Weather_conditions"] = order["Weather_conditions"].fillna("Unknown")
order["City"] = order["City"].fillna("Unknown")
order["Festival"] = order["Festival"].fillna("Unknown")
order["Road_traffic_density"] = order["Road_traffic_density"].fillna("Unknown")


order.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken (min)                  0
# dtype: int64

# %%
order[order["Time_Orderd"].isnull()]["Time_taken (min)"].isnull().sum()
# Out:
# np.int64(0)

# %%
order["Time_Orderd"] = order["Time_Orderd"].fillna("Unknown")

# %%
order.isnull().sum()[order.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
order.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries            float64
# Festival                        object
# City                            object
# Time_taken (min)                 int64
# dtype: object

# %%
order["Order_Date"] = pd.to_datetime(order["Order_Date"], format='mixed', errors="coerce")


order["Order_Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
order["Weather_conditions"].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny',
#        'Unknown'], dtype=object)

# %%
categorical_columns = [
    "Weather_conditions",
    "Road_traffic_density",
    "Type_of_order",
    "Type_of_vehicle",
    "Festival",
    "City"
]

for col in categorical_columns:
    print(f"\n--- {col} ---")
    print(order[col].unique())
# Out:
# --- Weather_conditions ---
# ['Fog' 'Stormy' 'Sandstorms' 'Windy' 'Cloudy' 'Sunny' 'Unknown']
#
# --- Road_traffic_density ---
# ['Jam' 'High' 'Medium' 'Low' 'Unknown']
#
# --- Type_of_order ---
# ['Snack' 'Meal' 'Drinks' 'Buffet']
#
# --- Type_of_vehicle ---
# ['motorcycle' 'scooter' 'electric_scooter' 'bicycle']
#
# --- Festival ---
# ['No' 'Yes' 'Unknown']
#
# --- City ---
# ['Metropolitian' 'Urban' 'Semi-Urban' 'Unknown']

# %%
order.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         45584.000000             45584.000000         45584.000000
# mean             29.584525                 4.636546            17.017948
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.600000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              34.000000                 4.800000            22.728163
# max              50.000000                 6.000000            30.914057
# std               5.696221                 0.327931             8.185674
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45584.000000                45584.000000
# mean              70.229684                   17.465480
# min              -88.366217                    0.010000
# 25%               73.170000                   12.988453
# ...

# %%
order["Delivery_person_Ratings"].value_counts().sort_index()
# Out:
# Delivery_person_Ratings
# 1.0      38
# 2.5      20
# 2.6      22
# 2.7      22
# 2.8      19
# 2.9      19
# 3.0       6
# 3.1      29
# 3.2      29
# 3.3      25
# 3.4      32
# 3.5     249
# 3.6     207
# 3.7     225
# 3.8     228
# 3.9     197
# 4.0    1077
# 4.1    1430
# 4.2    1418
# 4.3    1409
# 4.4    1360
# 4.5    3302
# 4.6    6938
# 4.7    9048
# 4.8    7146
# 4.9    7040
# 5.0    3996
# 6.0      53
# Name: count, dtype: int64

# %%
import  numpy as np 
order.loc[order["Delivery_person_Ratings"] > 5, "Delivery_person_Ratings"] = np.nan

# %%
order["Delivery_person_Ratings"].isnull().sum()
# Out:
# np.int64(53)

# %%
order["Delivery_person_Ratings"] = order["Delivery_person_Ratings"].fillna(
    order["Delivery_person_Ratings"].median()
)

# %%
order["Delivery_person_Ratings"].isnull().sum()
# Out:
# np.int64(0)

# %%
order["Vehicle_condition"].value_counts().sort_index()
# Out:
# Vehicle_condition
# 0    15005
# 1    15028
# 2    15031
# 3      520
# Name: count, dtype: int64

# %%
order["multiple_deliveries"].value_counts(dropna=False).sort_index()
# Out:
# multiple_deliveries
# 0.0    14094
# 1.0    29144
# 2.0     1985
# 3.0      361
# Name: count, dtype: int64

# %%
order[order["Time_taken (min)"] <= 0].shape
# Out:
# (0, 20)

# %%
order[
    (order["Delivery_person_Age"] < 18) |
    (order["Delivery_person_Age"] > 60)
].shape
# Out:
# (38, 20)

# %%
text_columns = [
    "ID",
    "Delivery_person_ID",
    "Time_Orderd",
    "Time_Order_picked",
    "Weather_conditions",
    "Road_traffic_density",
    "Type_of_order",
    "Type_of_vehicle",
    "Festival",
    "City"
]

for col in text_columns:
    order[col] = order[col].str.strip()

# %%
order.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
order.duplicated().sum()
# Out:
# np.int64(0)

# %%
order.shape
# Out:
# (45584, 20)

# %%
order.to_csv("food_delivery_cleaned.csv", index=False)

# %%
order.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
order.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         45584.000000             45584.000000         45584.000000
# mean             29.584525                 4.635034            17.017948
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.600000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              34.000000                 4.800000            22.728163
# max              50.000000                 5.000000            30.914057
# std               5.696221                 0.324623             8.185674
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45584.000000                45584.000000
# mean              70.229684                   17.465480
# min              -88.366217                    0.010000
# 25%               73.170000                   12.988453
# ...

# %%
print("--- Order Type ---")
print(order["Type_of_order"].value_counts())


print("\n--- City ---")
print(order["City"].value_counts())


print("\n--- Weather Conditions ---")
print(order["Weather_conditions"].value_counts())


print("\n--- Road Traffic Density ---")
print(order["Road_traffic_density"].value_counts())
# Out:
# --- Order Type ---
# Type_of_order
# Snack     11530
# Meal      11456
# Drinks    11321
# Buffet    11277
# Name: count, dtype: int64
#
# --- City ---
# City
# Metropolitian    34087
# Urban            10133
# Unknown           1200
# Semi-Urban         164
# Name: count, dtype: int64
#
# --- Weather Conditions ---
# Weather_conditions
# Fog           7653
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Sunny         7282
# Unknown        616
# Name: count, dtype: int64
#
# --- Road Traffic Density ---
# Road_traffic_density
# Low        15476
# Jam        14139
# Medium     10945
# High        4423
# Unknown      601
# Name: count, dtype: int64

# %%
print("=== Average Delivery Time by Order Type ===")
print(order.groupby("Type_of_order")["Time_taken (min)"].mean().sort_values(ascending=False))


print("\n=== Average Delivery Time by Traffic ===")
print(order.groupby("Road_traffic_density")["Time_taken (min)"].mean().sort_values(ascending=False))


print("\n=== Average Delivery Time by Weather ===")
print(order.groupby("Weather_conditions")["Time_taken (min)"].mean().sort_values(ascending=False))


print("\n=== Average Delivery Time by Vehicle ===")
print(order.groupby("Type_of_vehicle")["Time_taken (min)"].mean().sort_values(ascending=False))


print("\n=== Average Delivery Time by City ===")
print(order.groupby("City")["Time_taken (min)"].mean().sort_values(ascending=False))
# Out:
# === Average Delivery Time by Order Type ===
# Type_of_order
# Meal      26.417598
# Snack     26.285603
# Buffet    26.283320
# Drinks    26.187969
# Name: Time_taken (min), dtype: float64
#
# === Average Delivery Time by Traffic ===
# Road_traffic_density
# Jam        31.176038
# High       27.240109
# Medium     26.699680
# Unknown    26.542429
# Low        21.266671
# Name: Time_taken (min), dtype: float64
#
# === Average Delivery Time by Weather ===
# Weather_conditions
# Cloudy        28.917164
# Fog           28.914674
# Unknown       26.545455
# Windy         26.118836
# Sandstorms    25.875500
# Stormy        25.868803
# Sunny         21.856770
# Name: Time_taken (min), dtype: float64
#
# === Average Delivery Time by Vehicle ===
# Type_of_vehicle
# motorcycle          27.605774
# bicycle             26.426471
# scooter             24.478819
# electric_scooter    24.470110
# Name: Time_taken (min), dtype: float64
#
# === Average Delivery Time by City ===
# City
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))
sns.barplot(
    data=order,
    x="Road_traffic_density",
    y="Time_taken (min)",
    estimator="mean"
)
plt.title("Average Delivery Time by Traffic Density")
plt.xlabel("Traffic Density")
plt.ylabel("Average Delivery Time (min)")
plt.show()


plt.figure(figsize=(8, 4))
sns.barplot(
    data=order,
    x="Type_of_vehicle",
    y="Time_taken (min)",
    estimator="mean"
)
plt.title("Average Delivery Time by Vehicle Type")
plt.xlabel("Vehicle Type")
plt.ylabel("Average Delivery Time (min)")
plt.xticks(rotation=20)
plt.show()


plt.figure(figsize=(8, 4))
sns.barplot(
    data=order,
    x="Weather_conditions",
    y="Time_taken (min)",
    estimator="mean"
)
plt.title("Average Delivery Time by Weather")
plt.xlabel("Weather")
plt.ylabel("Average Delivery Time (min)")
plt.xticks(rotation=20)
plt.show()

# %%
order.groupby("City")["Time_taken (min)"].agg(
    ["count", "mean", "median", "min", "max"]
).sort_values("mean", ascending=False)
# Out:
#                count       mean  median  min  max
# City
# Semi-Urban       164  49.731707    49.0   44   54
# Metropolitian  34087  27.314460    26.0   10   54
# Urban          10133  22.983322    22.0   10   54
# Unknown         1200  22.058333    21.0   10   54

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    data=order,
    x="Time_taken (min)",
    bins=20
)

plt.title("Distribution of Delivery Time")
plt.xlabel("Delivery Time (minutes)")
plt.ylabel("Number of Orders")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=order,
    x="Type_of_order",
    y="Time_taken (min)",
    estimator="mean"
)

plt.title("Average Delivery Time by Order Type")
plt.xlabel("Order Type")
plt.ylabel("Average Delivery Time (min)")
plt.show()
